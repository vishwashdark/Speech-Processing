# %%
pip install librosa
# Out:
# ...
#
# ...

# %%
import librosa
y, sr = librosa.load("WhatsApp Ptt 2024-02-01 at 1.42.46 PM.ogg")
librosa.display.waveshow(y)

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import IPython.display as ipd

# A1: Load the recorded speech file
filename = "WhatsApp Ptt 2024-02-01 at 1.42.46 PM.ogg"  # Replace with the actual path to your speech file
y, sr = librosa.load(filename)

# A2: Plot the graph for the speech signal
librosa.display.waveshow(y)
plt.title('Speech Signal Waveform')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()

# A3: Observe the length & magnitude range of the signal
length_seconds = len(y) / sr
magnitude_range = max(y) - min(y)
print(f"Signal Length: {length_seconds} seconds")
print(f"Magnitude Range: {magnitude_range}")

# A4: Take a small segment of the signal and play it
start_time = 5  # Adjust the start time as needed
end_time = 10   # Adjust the end time as needed
segment = y[int(start_time * sr):int(end_time * sr)]

# Play the segment
ipd.Audio(segment, rate=sr)

# A5: Play around with various segments and observe the nature of the signal
# You can try different start and end times to extract different segments of the signal
# For example:
# segment_1 = y[int(start_time_1 * sr):int(end_time_1 * sr)]
# segment_2 = y[int(start_time_2 * sr):int(end_time_2 * sr)]

# Plotting different segments
librosa.display.waveshow(segment_1)
plt.title('Segment 1 Waveform')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()

librosa.display.waveshow(segment_2)
plt.title('Segment 2 Waveform')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()
# Out:
# Signal Length: 2.477823129251701 seconds
# Magnitude Range: 1.1845232248306274
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 29
#      26 segment = y[int(start_time * sr):int(end_time * sr)]
#      28 # Play the segment
# ---> 29 ipd.Audio(segment, rate=sr)
#      31 # A5: Play around with various segments and observe the nature of the signal
#      32 # You can try different start and end times to extract different segments of the signal
#      33 # For example:
#    (...)
#      36
#      37 # Plotting different segments
#      38 librosa.display.waveshow(segment_1)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\lib\display.py:130, in Audio.__init__(self, data, filename, url, embed, rate, autoplay, normalize, element_id)
#     128 if rate is None:
# ...
