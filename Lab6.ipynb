# %%
import librosa
import librosa.display
import IPython
import matplotlib.pyplot as plt
import numpy as np

# %%
"""A1. Take a portion of your recorded signal which represents a vowel sound. Perform FFT on the
signal snippet and observe the amplitude spectrum. Repeat the same for a few vowel sounds."""

Sound1="Bat.ogg"
Sound2="Bit.ogg"
Sound3="Boat.ogg"

# %%
# 1st vowel Bat
def plotfft(y,n):
    plt.plot(np.abs(np.fft.fft(y)))
    plt.xlabel("Frequency")
    plt.ylabel("Amplitude")
    plt.title("FFT of "+n+" Sound")
y1,sr=librosa.load(Sound1)
def plotwaveform(x,n):
    plt.plot(x)
    plt.xlabel("Time")
    plt.ylabel("Amplitude")
    plt.title("Waveform of "+n+" Sound")
plotfft(y1,"Bat")
y2,sr=librosa.load(Sound2)
y3,sr=librosa.load(Sound3)

# %%
plotwaveform(y1,"Bat")

# %%
plotwaveform(y2,"Bit")

# %%
#2nd Plot Bit
y2,sr=librosa.load(Sound2)
plotfft(y2,"Bit")

# %%
plotwaveform(y3,"Boat")

# %%
#3rd plot Boat
y3,sr=librosa.load(Sound3)
plotfft(y3,"Boat")

# %%
"""Repeat the A1 for a consonant sound. Perform the same for a few consonant sounds."""
y4,sr=librosa.load("C:/Users/sharm/OneDrive/Desktop/Speech-Processing/Audio/Apple.ogg")
plotfft(y4,"Apple")

# %%
plotwaveform(y4,"Apple")

# %%
y5,sr=librosa.load("silence.ogg")
plotfft(y5,"Silence")

# %%
plotwaveform(y5,"Silence")

# %%
y6,sr=librosa.load("noise.ogg")
plotwaveform(y6,"Noise")

# %%
plotfft(y6,"Noise")

# %%
"""Now you have acquainted yourself with spectral amplitudes of various consonants and vowel-
based phonemes. Generate the spectrogram of the signal and observe the change points of the
signals with associated speech segments. Observe to identify the consonants and vowels from the
spectrogram."""

def plot_spectrogram(y,n):
    D = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)
    librosa.display.specshow(D, y_axis='linear')
    plt.colorbar(format='%+2.0f dB')
    plt.title("Spectrogram of "+n+" Sound")
    plt.xlabel("Time")
    plt.ylabel("Frequency")

plot_spectrogram(y1,"Bat Vowel")

# %%
plot_spectrogram(y2,"Bit Vowel")

# %%
plot_spectrogram(y3,"Boat Vowel")

# %%
plot_spectrogram(y4,"Apple Consonant")

# %%
plot_spectrogram(y5,"Silence")

# %%
plot_spectrogram(y6,"Noise")
