# %%
"""Load the recorded speech file into your python workspace.
 Once loaded, plot the graph for the speech signal.
 You may use the below code from librosa asa reference."""
import librosa
import matplotlib.pyplot as plt
y,sr=librosa.load("WhatsApp Ptt 2024-02-01 at 1.42.46 PM.ogg")
librosa.display.waveshow(y)

# %%
"""Observe the length & magnitude range of the signalfrom theplot. \
    Observing the plot, relate tothe spoken words and silence between the words."""
import librosa
import matplotlib.pyplot as plt

# Load the recorded speech file
y, sr = librosa.load("WhatsApp Ptt 2024-02-01 at 1.42.46 PM.ogg")

# Plot the graph for the speech signal
librosa.display.waveshow(y)

# Add labels and title to the plot
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.title("Speech Signal")

# Show the plot
plt.show()

# %%
""" relate tothe spoken words and silence between the words."""
import librosa
import matplotlib.pyplot as plt

# Load the recorded speech file
y, sr = librosa.load("WhatsApp Ptt 2024-02-01 at 1.42.46 PM.ogg")

# Plot the graph for the speech signal
librosa.display.waveshow(y)

# Add labels and title to the plot
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.title("Speech Signal")

# Show the plot
plt.show()

# %%
"""Take a small segment of the signal and play it. """
import librosa
import sounddevice as sd

# Load the recorded speech file
y, sr = librosa.load("WhatsApp Ptt 2024-02-01 at 1.42.46 PM.ogg")

# Take a small segment of the signal
segment = y[:100000000000000000]

# Play the segment
sd.play(segment, sr)

# %%
pip install sounddevice
# Out:
# ...
#      ---------------------------------------- 0.0/199.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/199.7 kB ? eta -:--:--
#      ------ --------------------------------- 30.7/199.7 kB ? eta -:--:--
#      ----------- ------------------------- 61.4/199.7 kB 812.7 kB/s eta 0:00:01
#      ----------- ------------------------- 61.4/199.7 kB 812.7 kB/s eta 0:00:01
#      ----------------- ------------------- 92.2/199.7 kB 521.8 kB/s eta 0:00:01
#      ---------------------- ------------- 122.9/199.7 kB 654.9 kB/s eta 0:00:01
#      ------------------------- ---------- 143.4/199.7 kB 607.9 kB/s eta 0:00:01
#      ----------------------------- ------ 163.8/199.7 kB 614.4 kB/s eta 0:00:01
#      ----------------------------- ------ 163.8/199.7 kB 614.4 kB/s eta 0:00:01
#      ----------------------------- ------ 163.8/199.7 kB 614.4 kB/s eta 0:00:01
#      -----------------------------------  194.6/199.7 kB 436.8 kB/s eta 0:00:01
# ...

# %%
import numpy as np
D = librosa.stft(y)
S_db = librosa.amplitude_to_db(np.abs(D), ref=np.max)
S_db.shape
img = librosa.display.specshow(S_db,
                              x_axis='time',
                              y_axis='log',
                              ax=ax)
ax.set_title('Spectogram Example', fontsize=20)
fig.colorbar(img, ax=ax, format=f'%0.2f')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 8
#       3 S_db = librosa.amplitude_to_db(np.abs(D), ref=np.max)
#       4 S_db.shape
#       5 img = librosa.display.specshow(S_db,
#       6                               x_axis='time',
#       7                               y_axis='log',
# ----> 8                               ax=ax)
#       9 ax.set_title('Spectogram Example', fontsize=20)
#      10 fig.colorbar(img, ax=ax, format=f'%0.2f')
#
# NameError: name 'ax' is not defined

# %%
"""Play around with your recorded speech signal for various segments. Understand the nature of the signal."
 Also observe with abruptly segmented speech, how the perception of that speech is affected."""
import librosa
import sounddevice as sd

# Load the recorded speech file
y, sr = librosa.load("WhatsApp Ptt 2024-02-01 at 1.42.46 PM.ogg")

# Take a small segment of the signal
segment1 = y[:10000]
segment2 = y[10000:20000]
segment3 = y[30000:20000]

# Play the segments
sd.play(segment1, sr)

# %%
sd.play(segment2, sr)

# %%
sd.play(segment3, sr)

# %%
""""Reverse the Audio file"""
import librosa
import sounddevice as sd
import numpy as np
